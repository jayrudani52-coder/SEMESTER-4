# %%
import pandas as pd
df=pd.read_csv("car data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]
print(x)
print(y)
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# 2         Manual      0
# 3         Manual      0
# 4         Manual      0
# ..           ...    ...
# 296       Manual      0
# 297       Manual      0
# 298       Manual      0
# 299       Manual      0
# 300       Manual      0
#
# [301 rows x 8 columns]
# 0         ritz
# 1          sx4
# 2         ciaz
# 3      wagon r
# 4        swift
#         ...
# 296       city
# 297       brio
# 298       city
# 299       city
# 300       brio
# Name: Car_Name, Length: 301, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (240, 8)
# (61, 8)
# (240,)
# (61,)

# %%
import pandas as pd
df=pd.read_csv("Advertising.csv")
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]
print(x)
print(y)
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 195    196
# 196    197
# 197    198
# 198    199
# 199    200
# Name: Unnamed: 0, Length: 200, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
x=df[["TV","Radio","Newspaper"]]
y=df["Sales"]
print(x.shape)
print(y.shape)
# Out:
# (200, 3)
# (200,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 3)
# (40, 3)
# (160,)
# (40,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(y_pred)
# Out:
# [21.73577184 16.45693776  7.65993185 17.89202679 18.67730671 23.86271904
#  16.33623628 13.45649226  9.177296   17.36056228 14.4677995   9.85697601
#  17.26057027 16.71866935 15.09530285 15.58923732 12.45188167 17.27925151
#  11.0944114  18.06889853  9.33433055 12.91345761  8.7842804  10.46670654
#  11.40303174 15.03104665  9.78479388 19.46028647 18.22954934 17.1958903
#  21.60304218 14.71901407 16.29205532 12.36432281 19.98831261 15.37556411
#  13.96678297 10.06809496 20.97197274  7.45877832]

# %%
diff=pd.DataFrame({"Actual":y_test,
                   "Predicted":y_pred})
diff
# Out:
#      Actual  Predicted
# 58     23.8  21.735772
# 40     16.6  16.456938
# 34      9.5   7.659932
# 102    14.8  17.892027
# 184    17.6  18.677307
# 198    25.5  23.862719
# 95     16.9  16.336236
# 4      12.9  13.456492
# 29     10.5   9.177296
# 168    17.1  17.360562
# 171    14.5  14.467799
# 18     11.3   9.856976
# 11     17.4  17.260570
# 89     16.7  16.718669
# 110    13.4  15.095303
# 118    15.9  15.589237
# 159    12.9  12.451882
# 35     12.8  17.279252
# 136     9.5  11.094411
# 59     18.4  18.068899
# 51     10.7   9.334331
# 16     12.5  12.913458
# 44      8.5   8.784280
# 94     11.5  10.466707
# 31     11.9  11.403032
# 162    14.9  15.031047
# 38     10.1   9.784794
# 28     18.9  19.460286
# 193    19.6  18.229549
# 27     15.9  17.195890
# 47     23.2  21.603042
# 165    11.9  14.719014
# 194    17.3  16.292055
# 177    11.7  12.364323
# 176    20.2  19.988313
# 97     15.5  15.375564
# 174    11.5  13.966783
# 73     11.0  10.068095
# 69     22.3  20.971973
# 172     7.6   7.458778

# %%
print("Coefficient:",lr.coef_)
print("Intercept:",lr.intercept_)
# Out:
# Coefficient: [0.0468431  0.17854434 0.00258619]
# Intercept: 2.9079470208164295

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
print("MAE : ",mean_absolute_error(y_test,y_pred))
print("MSE : ",mean_squared_error(y_test,y_pred))
print("R2_Score : ",r2_score(y_test,y_pred))
# Out:
# MAE :  1.0402154012924718
# MSE :  1.9918855518287906
# R2_Score :  0.8927605914615384

# %%
import pandas as pd
df=pd.read_csv("FuelConsumptionCo2.csv")
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# 1                   9.6                        29           221
# 2                   5.9                        48           136
# 3                  11.1                        25           255
# 4                  10.6                        27           244

# %%
df.drop(columns=["MAKE","MODEL","VEHICLECLASS","TRANSMISSION"],axis=1,inplace=True)
df.head()
# Out:
#    MODELYEAR  ENGINESIZE  CYLINDERS FUELTYPE  FUELCONSUMPTION_CITY  \
# 0       2014         2.0          4        Z                   9.9
# 1       2014         2.4          4        Z                  11.2
# 2       2014         1.5          4        Z                   6.0
# 3       2014         3.5          6        Z                  12.7
# 4       2014         3.5          6        Z                  12.1
#
#    FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# 0                  6.7                   8.5                        33
# 1                  7.7                   9.6                        29
# 2                  5.8                   5.9                        48
# 3                  9.1                  11.1                        25
# 4                  8.7                  10.6                        27
#
#    CO2EMISSIONS
# 0           196
# 1           221
# 2           136
# 3           255
# 4           244

# %%
df["Age"]=2026-df["MODELYEAR"]
df
# Out:
#       MODELYEAR  ENGINESIZE  CYLINDERS FUELTYPE  FUELCONSUMPTION_CITY  \
# 0          2014         2.0          4        Z                   9.9
# 1          2014         2.4          4        Z                  11.2
# 2          2014         1.5          4        Z                   6.0
# 3          2014         3.5          6        Z                  12.7
# 4          2014         3.5          6        Z                  12.1
# ...         ...         ...        ...      ...                   ...
# 1062       2014         3.0          6        X                  13.4
# 1063       2014         3.2          6        X                  13.2
# 1064       2014         3.0          6        X                  13.4
# 1065       2014         3.2          6        X                  12.9
# 1066       2014         3.2          6        X                  14.9
#
#       FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# 0                     6.7                   8.5                        33
# 1                     7.7                   9.6                        29
# 2                     5.8                   5.9                        48
# 3                     9.1                  11.1                        25
# 4                     8.7                  10.6                        27
# ...                   ...                   ...                       ...
# 1062                  9.8                  11.8                        24
# 1063                  9.5                  11.5                        25
# 1064                  9.8                  11.8                        24
# 1065                  9.3                  11.3                        25
# 1066                 10.2                  12.8                        22
#
#       CO2EMISSIONS  Age
# 0              196   12
# 1              221   12
# 2              136   12
# 3              255   12
# 4              244   12
# ...            ...  ...
# 1062           271   12
# 1063           264   12
# 1064           271   12
# 1065           260   12
# 1066           294   12
#
# [1067 rows x 10 columns]

# %%
df.drop(columns=["MODELYEAR"],inplace=True)
df
# Out:
#       ENGINESIZE  CYLINDERS FUELTYPE  FUELCONSUMPTION_CITY  \
# 0            2.0          4        Z                   9.9
# 1            2.4          4        Z                  11.2
# 2            1.5          4        Z                   6.0
# 3            3.5          6        Z                  12.7
# 4            3.5          6        Z                  12.1
# ...          ...        ...      ...                   ...
# 1062         3.0          6        X                  13.4
# 1063         3.2          6        X                  13.2
# 1064         3.0          6        X                  13.4
# 1065         3.2          6        X                  12.9
# 1066         3.2          6        X                  14.9
#
#       FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# 0                     6.7                   8.5                        33
# 1                     7.7                   9.6                        29
# 2                     5.8                   5.9                        48
# 3                     9.1                  11.1                        25
# 4                     8.7                  10.6                        27
# ...                   ...                   ...                       ...
# 1062                  9.8                  11.8                        24
# 1063                  9.5                  11.5                        25
# 1064                  9.8                  11.8                        24
# 1065                  9.3                  11.3                        25
# 1066                 10.2                  12.8                        22
#
#       CO2EMISSIONS  Age
# 0              196   12
# 1              221   12
# 2              136   12
# 3              255   12
# 4              244   12
# ...            ...  ...
# 1062           271   12
# 1063           264   12
# 1064           271   12
# 1065           260   12
# 1066           294   12
#
# [1067 rows x 9 columns]

# %%
df.corr(numeric_only=True)
# Out:
#                           ENGINESIZE  CYLINDERS  FUELCONSUMPTION_CITY  \
# ENGINESIZE                  1.000000   0.934011              0.832225
# CYLINDERS                   0.934011   1.000000              0.796473
# FUELCONSUMPTION_CITY        0.832225   0.796473              1.000000
# FUELCONSUMPTION_HWY         0.778746   0.724594              0.965718
# FUELCONSUMPTION_COMB        0.819482   0.776788              0.995542
# FUELCONSUMPTION_COMB_MPG   -0.808554  -0.770430             -0.935613
# CO2EMISSIONS                0.874154   0.849685              0.898039
# Age                              NaN        NaN                   NaN
#
#                           FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  \
# ENGINESIZE                           0.778746              0.819482
# CYLINDERS                            0.724594              0.776788
# FUELCONSUMPTION_CITY                 0.965718              0.995542
# FUELCONSUMPTION_HWY                  1.000000              0.985804
# FUELCONSUMPTION_COMB                 0.985804              1.000000
# FUELCONSUMPTION_COMB_MPG            -0.893809             -0.927965
# CO2EMISSIONS                         0.861748              0.892129
# Age                                       NaN                   NaN
#
#                           FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS  Age
# ENGINESIZE                               -0.808554      0.874154  NaN
# CYLINDERS                                -0.770430      0.849685  NaN
# FUELCONSUMPTION_CITY                     -0.935613      0.898039  NaN
# FUELCONSUMPTION_HWY                      -0.893809      0.861748  NaN
# FUELCONSUMPTION_COMB                     -0.927965      0.892129  NaN
# FUELCONSUMPTION_COMB_MPG                  1.000000     -0.906394  NaN
# CO2EMISSIONS                             -0.906394      1.000000  NaN
# Age                                            NaN           NaN  NaN

# %%
x=df[["ENGINESIZE","CYLINDERS","FUELCONSUMPTION_COMB"]]
y=df["CO2EMISSIONS"]
print(x.shape)
print(y.shape)
# Out:
# (1067, 3)
# (1067,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (853, 3)
# (214, 3)
# (853,)
# (214,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(y_pred)
# Out:
# [257.0729753  193.62675365 198.61947156 184.0315625  308.84886971
#  222.06199356 185.00408977 193.38929893 234.70484808 197.40948958
#  217.83256226 260.96308439 200.32707139 363.64971908 200.51083953
#  192.73062136 193.99428993 314.31649706 261.88192508 215.88750772
#  440.76775066 216.07127586 254.46924319 258.96434327 279.75495223
#  239.56748443 162.03372438 288.13465573 187.18659903 231.68539877
#  229.84221172 367.53982816 246.32148875 360.70666476 285.37813365
#  315.9704103  351.66277803 181.16766727 341.17972436 257.62427972
#  239.56748443 373.66062742 215.15243517 257.20305686 256.41429773
#  201.53705338 189.73664457 161.53335371 181.11398069 250.02782969
#  189.13165357 336.15602827 329.4839246  344.85508713 211.26232608
#  269.05715225 208.29105769 289.16086958 263.22198863 185.24154449
#  209.07981683 238.80693936 209.31727154 194.72936248 215.15243517
#  193.38929893 259.33187954 253.31294778 204.45463519 209.55472626
#  211.26232608 211.26232608 302.91183859 245.34896148 354.32019672
#  316.65179628 177.22387161 308.87157811 204.45463519 262.24946136
#  336.10234169 184.87400821 310.87031923 325.14437859 211.26232608
#  353.60783257 254.65301133 253.12917964 205.42716246 248.45031143
#  342.22864661 294.86595164 185.00408977 249.23907056 211.26232608
#  204.45463519 342.22864661 391.90119085 218.07001698 288.29571546
#  211.99739864 335.12981442 216.12496244 264.79950689 203.71956263
#  294.86595164 191.44424439 360.70666476 198.25193529 204.45463519
#  219.7776168  362.360578   361.07420103 305.56375162 360.70666476
#  254.10170691 209.26358496 216.07127586 321.25426951 198.61947156
#  255.6255386  278.91250652 203.48210792 262.24946136 191.81178067
#  208.34474427 318.6505374  330.32086465 324.59307418 201.53705338
#  211.99739864 187.18659903 263.03822049 321.38985673 390.85501015
#  322.64801964 386.41359665 194.9668172  308.19019214 224.64025316
#  185.84653548 209.31727154 205.42716246 173.80867196 286.66451062
#  205.42716246 369.88063305 350.19263292 315.9704103  264.98327503
#  203.48210792 254.15539349 368.06291851 345.69753284 232.70610696
#  205.37347588 283.27752504 329.2946508  193.38929893 197.64694429
#  179.40638087 247.47778416 278.3612021  181.9564264  261.93561166
#  316.70548286 228.76781696 255.07423418 313.78790104 235.62368877
#  324.49120668 292.49967424 292.18582454 189.13165357 323.19932405
#  258.04550257 387.64628704 252.9454115  167.55228548 440.76775066
#  302.88362452 360.70666476 251.23781168 191.68169911 302.72807045
#  248.26654329 228.53036224 244.37643421 309.53576135 183.90148094
#  207.372217   185.24154449 206.16223501 377.97195936 294.86595164
#  268.87338411 253.12917964 250.02782969 323.51317375 294.86595164
#  244.37643421 258.54312041 257.01928873 305.8294204  262.06569322
#  212.23485335 189.13165357 253.68048406 219.7776168  275.68107501
#  189.13165357 266.32333858 262.24946136 169.44365344]

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x,y)
y_pred=lr.predict(x)
print(y)
# Out:
# 0       196
# 1       221
# 2       136
# 3       255
# 4       244
#        ...
# 1062    271
# 1063    264
# 1064    271
# 1065    260
# 1066    294
# Name: CO2EMISSIONS, Length: 1067, dtype: int64

# %%
print("Coefficient:",lr.coef_)
print("Intercept:",lr.intercept_)
# Out:
# Coefficient: [10.85524041  7.51622501  9.59563161]
# Intercept: 65.22328417194541

# %%
import pandas as pd
df=pd.read_csv("polylinearregression.csv")
df
# Out:
#    sno  Temperature  Pressure
# 0    1            0    0.0002
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900
# 5    6          100    0.2700

# %%
x=df.iloc[:,1:2]
y=df.iloc[:,-1]
print(x.shape)
print(y.shape)
# Out:
# (6, 1)
# (6,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4, 1)
# (2, 1)
# (4,)
# (2,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x,y)
y_pred=lr.predict(x)
print(y_pred)
# Out:
# [-0.05086667 -0.00402667  0.04281333  0.08965333  0.13649333  0.18333333]

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2)
x_poly=poly.fit_transform(x)
print(x_poly)
# Out:
# [[1.0e+00 0.0e+00 0.0e+00]
#  [1.0e+00 2.0e+01 4.0e+02]
#  [1.0e+00 4.0e+01 1.6e+03]
#  [1.0e+00 6.0e+01 3.6e+03]
#  [1.0e+00 8.0e+01 6.4e+03]
#  [1.0e+00 1.0e+02 1.0e+04]]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,5))
plt.scatter(x,y,color="blue")
plt.plot(x,y_pred,color="red")
plt.show()

# %%
import pandas as pd
df=pd.read_csv("car_data.csv")
df
# Out:
#    Horsepower  Weight  MPG
# 0         130    3504   18
# 1         165    3693   15
# 2         150    3436   18
# 3         140    3433   16
# 4         198    4341   14
# 5         220    4354   12
# 6          95    2372   25
# 7          88    2130   27
# 8          98    2228   24

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]
print(x.shape)
print(y.shape)
# Out:
# (9, 2)
# (9,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x,y)
y_pred=lr.predict(x)
print(y_pred)
# Out:
# [154.15411714 165.04650997 150.84859343 151.83941574 197.11453361
#  198.88312619  95.14857971  82.24814993  88.71697427]

# %%
diff=pd.DataFrame({"Actual":y,
                   "Predicted":y_pred})
diff
# Out:
#    Actual   Predicted
# 0     130  154.154117
# 1     165  165.046510
# 2     150  150.848593
# 3     140  151.839416
# 4     198  197.114534
# 5     220  198.883126
# 6      95   95.148580
# 7      88   82.248150
# 8      98   88.716974

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2)
x_poly=poly.fit_transform(x)
print(x_poly)
# Out:
# [[1.0000000e+00 3.5040000e+03 1.8000000e+01 1.2278016e+07 6.3072000e+04
#   3.2400000e+02]
#  [1.0000000e+00 3.6930000e+03 1.5000000e+01 1.3638249e+07 5.5395000e+04
#   2.2500000e+02]
#  [1.0000000e+00 3.4360000e+03 1.8000000e+01 1.1806096e+07 6.1848000e+04
#   3.2400000e+02]
#  [1.0000000e+00 3.4330000e+03 1.6000000e+01 1.1785489e+07 5.4928000e+04
#   2.5600000e+02]
#  [1.0000000e+00 4.3410000e+03 1.4000000e+01 1.8844281e+07 6.0774000e+04
#   1.9600000e+02]
#  [1.0000000e+00 4.3540000e+03 1.2000000e+01 1.8957316e+07 5.2248000e+04
#   1.4400000e+02]
#  [1.0000000e+00 2.3720000e+03 2.5000000e+01 5.6263840e+06 5.9300000e+04
#   6.2500000e+02]
#  [1.0000000e+00 2.1300000e+03 2.7000000e+01 4.5369000e+06 5.7510000e+04
#   7.2900000e+02]
#  [1.0000000e+00 2.2280000e+03 2.4000000e+01 4.9639840e+06 5.3472000e+04
#   5.7600000e+02]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_poly,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (7, 6)
# (2, 6)
# (7,)
# (2,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print(y_pred)
# Out:
# [115.43684543 132.17090308]

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
print("MAE : ",mean_absolute_error(y_test,y_pred))
print("MSE : ",mean_squared_error(y_test,y_pred))
print("R2_Score : ",r2_score(y_test,y_pred))
# Out:
# MAE :  17.632971174354225
# MSE :  310.9601377431865
# R2_Score :  0.5399997962378897

# %%
import pandas as pd
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

x=[1,2,3,4,5]
y=[1,4,9,16,25]
x=pd.DataFrame(x)
y=pd.Series(y)

poly=PolynomialFeatures(degree=2)
x_poly=poly.fit_transform(x)
model=LinearRegression()
model.fit(x_poly,y)
y_pred=model.predict(x_poly)
print(y_pred)
print("R2_Score:",r2_score(y,y_pred))
# Out:
# [ 1.  4.  9. 16. 25.]
# R2_Score: 1.0
