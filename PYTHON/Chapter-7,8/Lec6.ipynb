# %%
import requests
from datetime import datetime 
response=requests.get("https://api.github.com/rate_limit")
data=response.json()
print("Limits",data["rate"]["limit"])
print("Used:",data["rate"]["used"])
print("Left:",data["rate"]["remaining"])
print("Reset:",data["rate"]["reset"])
reset_stamp=data["rate"]["reset"]
reset_time=datetime.fromtimestamp(reset_stamp).strftime("%y-%m-%d %H:%M:%S")
print(reset_time)
# Out:
# Limits 60
# Used: 18
# Left: 42
# Reset: 1780462555
# 26-06-03 10:25:55

# %%
import requests
for i in range(70):
    response=requests.get("https://api.github.com/users/octocat")
    print(i+1,response.status_code)
    if response.status_code==403:
        data=response.json()
        if "API rate limit exceeded" in data.get("message",''):
            print("Rate Limit Exceeded")
            print(data["message"])
            break
# Out:
# 1 200
# 2 200
# 3 200
# 4 200
# 5 200
# 6 200
# 7 200
# 8 200
# 9 200
# 10 200
# 11 200
# 12 200
# 13 200
# 14 200
# 15 200
# 16 200
# 17 200
# 18 200
# 19 200
# 20 200
# 21 200
# 22 200
# 23 200
# 24 200
# 25 200
# 26 200
# 27 200
# 28 200
# 29 200
# 30 200
# 31 200
# 32 200
# 33 200
# 34 200
# 35 200
# 36 200
# 37 200
# 38 200
# 39 200
# 40 200
# 41 403
# Rate Limit Exceeded
# API rate limit exceeded for 49.200.158.178. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)
